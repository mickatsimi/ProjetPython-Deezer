# %%
INSTALLATION DE LA LIBRAIRIE NECESSAIRE AU BON FONCTIONNEMENT DU PROGRAMME

# %%
pip install deezer-python
# Out:
# Collecting deezer-python
#   Downloading deezer_python-4.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests<3.0,>=2.18 in /usr/local/lib/python3.7/dist-packages (from deezer-python) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.18->deezer-python) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.18->deezer-python) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.18->deezer-python) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.18->deezer-python) (2021.10.8)
# Installing collected packages: deezer-python
# Successfully installed deezer-python-4.3.0

# %%
import deezer as dp

# %% [markdown]
# ACCES VIA LES CODES DE CONNEXION A L'API DEEZER

# %%
client = dp.Client(app_id='mickaeltsimi@yahoo.fr', app_secret='Mickael1')

# %%
nom_artiste=input("inserez le nom de l'artiste que vous souhaitez : ")
artiste=client.get_artist(nom_artiste)
print(artiste)
# Out:
# inserez le nom de l'artiste que vous souhaitez : Drake
# <Artist: Drake>

# %% [markdown]
# TRAVAIL SUR ARTISTES

# %%
albums_de_lartiste=artiste.get_albums()[0].get_tracks()
print(albums_de_lartiste)
# Out:
# [<Track: Champagne Poetry>, <Track: Papi’s Home>, <Track: Girls Want Girls>, <Track: In The Bible>, <Track: Love All>, <Track: Fair Trade>, <Track: Way 2 Sexy>, <Track: TSU>, <Track: N 2 Deep>, <Track: Pipe Down>, <Track: Yebba’s Heartbreak>, <Track: No Friends In The Industry>, <Track: Knife Talk>, <Track: 7am On Bridle Path>, <Track: Race My Mind>, <Track: Fountains>, <Track: Get Along Better>, <Track: You Only Live Twice>, <Track: IMY2>, <Track: F*****g Fans>, <Track: The Remorse>]

# %%
for j in range(len(artiste.get_albums())):
    
    cpt=0
    alb=artiste.get_albums()[j].get_tracks()
    if len(alb)>1: #no single
        for elt in range(len(alb)):
            #print(alb[elt]) 
            if "feat." in str(alb[elt]):
                cpt+=1
        print("nom album: ",artiste.get_albums()[j]," nombre de feats: ",cpt," nombre de sons: ",len(alb))
# Out:
# nom album:  <Album: Certified Lover Boy>  nombre de feats:  0  nombre de sons:  21
# nom album:  <Album: Certified Lover Boy>  nombre de feats:  0  nombre de sons:  21
# nom album:  <Album: Dark Lane Demo Tapes>  nombre de feats:  0  nombre de sons:  14
# nom album:  <Album: Care Package>  nombre de feats:  0  nombre de sons:  17
# nom album:  <Album: Scorpion>  nombre de feats:  0  nombre de sons:  25
# nom album:  <Album: More Life>  nombre de feats:  0  nombre de sons:  22
# nom album:  <Album: Views>  nombre de feats:  0  nombre de sons:  20
# nom album:  <Album: What A Time To Be Alive>  nombre de feats:  0  nombre de sons:  11
# nom album:  <Album: If You're Reading This It's Too Late>  nombre de feats:  0  nombre de sons:  17
# nom album:  <Album: Nothing Was The Same>  nombre de feats:  0  nombre de sons:  13
# nom album:  <Album: Nothing Was The Same (Deluxe)>  nombre de feats:  0  nombre de sons:  15
# nom album:  <Album: Take Care (Deluxe)>  nombre de feats:  0  nombre de sons:  19
# nom album:  <Album: Thank Me Later>  nombre de feats:  0  nombre de sons:  14
# nom album:  <Album: So Far Gone>  nombre de feats:  0  nombre de sons:  18
# nom album:  <Album: Scary Hours 2>  nombre de feats:  0  nombre de sons:  3
# nom album:  <Album: The Best In The World Pack>  nombre de feats:  0  nombre de sons:  2

# %%
nbr=artiste.get_albums()
for i in range (len(nbr)):
  somme =0
  for j in range(len(nbr[i].get_tracks())):
    if len(nbr[i].get_tracks())<2:
      print("C'est un single")
    else:
      
      somme=somme+nbr[i].get_tracks()[j].duration
  print("l'album",nbr[i],"dure",(somme/60),"minutes")

# %%
a=input('choisissez votre artiste de départ : ')
artiste=client.get_artist(a)
for j in artiste.get_related():
  print('------------------------')
  print(j.name)
  print('------------------------')
  for i in range(5):
    print(j.get_top()[i].title)

# %% [markdown]
# **TRAVAIL SUR PLAYLIST **

# %%
client2 = dp.Client(app_id='mickaeltsimi@yahoo.fr', app_secret='Mickael1')

# %%
liste=[]
id=1767932902
for i in range(len(client2.get_playlist(id).get_tracks())):
  liste.append(client2.get_playlist(id).get_tracks()[i].get_artist())
  print(client2.get_playlist(id).get_tracks()[i].get_artist())
# Out:
# <Artist: B.B. King>
# <Artist: Dinah Washington>
# <Artist: Sister Rosetta Tharpe>
# <Artist: Sonny Boy Williamson>
# <Artist: Aretha Franklin>
# <Artist: Howlin' Wolf>
# <Artist: Big Mama Thornton>
# <Artist: Jimi Hendrix>
# <Artist: Muddy Waters>
# <Artist: John Lee Hooker>
# <Artist: Otis Rush>
# <Artist: Chuck Berry>
# <Artist: Sonny Boy Williamson>
# <Artist: Little Walter>
# <Artist: Big Mama Thornton>
# <Artist: The Rolling Stones>
# <Artist: Muddy Waters>
# <Artist: Bessie Smith>
# <Artist: Buddy Guy>
# <Artist: Eric Clapton>
# <Artist: Etta James>
# <Artist: Howlin' Wolf>
# <Artist: Bettye LaVette>
# <Artist: Robert Johnson>
# <Artist: Otis Taylor>
# 25

# %% [markdown]
# CREATION DE PLAYLIST EN LIEN AVEC LES ARTISTES DU TOP France 2021

# %%
l=[]
for i in range(len(client2.get_playlist(id).get_tracks())):
  print(client2.get_playlist(id).get_tracks()[i].get_artist())
  print('Playlist Découverte')
  for j in client2.get_playlist(id).get_tracks()[i].get_artist().get_related():
    print('------------------------')
    print(j.name)
    print('------------------------')
    for k in range(len(j.get_top())):
      print(j.get_top()[k].title)
      
    
    

###print(len(client2.get_playlist(id).get_tracks()[i].get_artist().get_related()))
# Out:
# <Artist: B.B. King>
# Playlist Découverte
# ------------------------
# Eric Clapton
# ------------------------
# Cocaine
# Cocaine
# Tears in Heaven
# Layla (Acoustic; Live at MTV Unplugged, Bray Film Studios, Windsor, England, UK, 1/16/1992; 1999 Remaster)
# Wonderful Tonight
# ------------------------
# Guatemala Choir
# ------------------------
# We Are The World (Live)
# ------------------------
# Ars Canto G. Verdi
# ------------------------
# We Are The World (Live)
# All You Need Is Love
# Funiculì, funiculà
# Agnus Dei
# Cielito lindo
# ------------------------
# Trey Lorenz
# ------------------------
# We Are The World (Live)
# Make You Happy (Album Version)
# Someone to Hold
# Always In Love (Album Version)
# Pisces (Alternate Mix)
# ------------------------
# Renato Zero
# ------------------------
# We Are The World (Live)
# Padre nostro (Remastered 2019)
# Guai (Remastered 2019)
# La gente come noi (Remastered 2019)
# I migliori anni della nostra vita (Remastered 2019)
# ------------------------
# Rob Mathes
# ------------------------
# We Are The World (Live)
# Se Bastasse Una Canzone
# Il Gladiatore
# Let It Rain
# ------------------------
# The Rolling Stones
# ------------------------
# Paint It, Black
# Start Me Up
# Gimme Shelter
# (I Can't Get No) Satisfaction
# Sympathy For The Devil
# ------------------------
# Deep Purple
# ------------------------
# Smoke on the Water
# Highway Star
# Hush (1998 Remix)
# Perfect Strangers
# Burn (2002 Remaster)
# ------------------------
# Popa Chubby
# ------------------------
# Same Old Blues (Album Version)
# Blues for Charlie
# Hey Joe
# Embee's Song
# Stoop Down Baby (Album Version)
# ------------------------
# Led Zeppelin
# ------------------------
# Stairway to Heaven (Remaster)
# Whole Lotta Love (Remaster)
# Immigrant Song (Remaster)
# Black Dog (Remaster)
# Kashmir (Remaster)
# ------------------------
# Junior Wells' Chicago Blues Band
# ------------------------
# Ships on the Ocean
# Yonder Wall (Alternative Take 11)
# In the Wee Wee Hours (Alternative)
# Studio Chatter 5
# Chitlins Con Carne (Alternative)
# <Artist: Eric Clapton>
# Playlist Découverte
# ------------------------
# B.B. King
# ------------------------
# The Thrill Is Gone
# Lucille
# We Are The World (Live)
# Paying The Cost To Be The Boss
# Riding with the King
# ------------------------
# The Rolling Stones
# ------------------------
# Paint It, Black
# Start Me Up
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d5b7113c75d4> in <module>()
#       8     print('------------------------')
#       9     for k in range(len(j.get_top())):
# ---> 10       print(j.get_top()[k].title)
#      11
#      12
#
# /usr/local/lib/python3.7/dist-packages/deezer/resources.py in get_top(self, **kwargs)
#     189         :returns: list of :mod:`Track <deezer.resources.Track>` instances
#     190         """
# --> 191         return self.get_relation("top", **kwargs)
#     192
#     193     def get_related(self, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/deezer/resources.py in get_relation(self, relation, **kwargs)
#      68             f"{self.type}/{self.id}/{relation}",
#      69             parent=self,
# ---> 70             **kwargs,
#      71         )
#      72
#
# /usr/local/lib/python3.7/dist-packages/deezer/client.py in request(self, method, path, parent, resource_type, **params)
#     141             method,
#     142             f"{self.base_url}/{path}",
# --> 143             params=params,
#     144         )
#     145         try:
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# TOP 5 DES SONS DES ARTISTES DU TOP 25 FRANCE

# %%
for i in range(len(client2.get_playlist(id).get_tracks())):
  print(client2.get_playlist(id).get_tracks()[i].get_artist())
  print(client2.get_playlist(id).get_tracks()[i].get_artist().get_top())

# %% [markdown]
# ALBUM LE PLUS Recent DES ARTISTES DU TOP 25

# %%
for i in range(len(client2.get_playlist(id).get_tracks())):
  print(client2.get_playlist(id).get_tracks()[i].get_artist())
  print(client2.get_playlist(id).get_tracks()[i].get_artist().get_albums()[0])
  print(client2.get_playlist(id).get_tracks()[i].get_artist().get_albums()[0].release_date)

# %% [markdown]
# GENERATEUR DE PLAYLIST

# %%
a=input('choisissez votre artiste de départ : ')
artiste=client.get_artist(a)
for j in artiste.get_related():
  print('------------------------')
  print(j.name)
  print('------------------------')
  for i in range(5):
    print(j.get_top()[i].title)
